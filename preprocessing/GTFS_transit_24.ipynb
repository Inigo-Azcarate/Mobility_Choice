# %% [markdown]
# # Import libraries and mount drive

# %%
# import numpy as np
# #import pandas as pd
# import os
# import glob
# #import matplotlib.pyplot as plt
# import statistics
# import seaborn as sns
# from pathlib import Path
# import re
# import requests
# from io import StringIO
# import random
# import pdb

# import matplotlib
# matplotlib.use('agg')  # allows notebook to be tested in Travis

# import pandas as pd
# #import cartopy.crs as ccrs
# #import cartopy
# import matplotlib.pyplot as plt
# #import pandana as pdna
# import time

# !pip install pandana
# import pandana as pdna

# # !pip install cartopy
# # import cartopy.crs as ccrs
# # import cartopy

# !pip install urbanaccess
# import urbanaccess as ua
# from urbanaccess.config import settings
# from urbanaccess.gtfsfeeds import feeds
# from urbanaccess import gtfsfeeds
# from urbanaccess.gtfs.gtfsfeeds_dataframe import gtfsfeeds_dfs
# from urbanaccess.network import ua_network, load_network

# %matplotlib inline

# %% [markdown]
# # Load data to an Urban Access transit data object

# %%
# I manually add all the feeds from the bus transit companies of Gipuzkoa

# feeds.add_feed(add_dict={'dbus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/dbus/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_areizaga': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_areizaga/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_arrasate': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_arrasate/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_auif_urb': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_auif_urb/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_eibar': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_eibar/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_ekialdebus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_ekialdebus/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_euskotren_bus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_euskotren_bus/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_garayar': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_garayar/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_gipuzkoana': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_gipuzkoana/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_goierrialdea': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_goierrialdea/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_hernani': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_hernani/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_lasarte': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_lasarte/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_oiartzun': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_oiartzun/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_pesa': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_pesa/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_renteria': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_renteria/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_tbh': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_tbh/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_tolosaldea': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_tolosaldea/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_tsst': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_tsst/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_zarautz': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_zarautz/google_transit.zip'})

# %%
# I download all these feeds, 40sg
# gtfsfeeds.download()

# %% [markdown]
# Let's specify a bounding box of coordinates for Gipuzkoa to subset the GTFS data to. You can generate a bounding box by going to http://boundingbox.klokantech.com/ and selecting the CSV format.

# %%
# # Load GTFS data into an UrbanAcess transit data object
# validation = True
# verbose = True
# # bbox for Gipuzkoa
# Lat_min = 42.904155
# Long_min = -2.621987
# Lat_max = 43.403070
# Long_max = -1.740334
# bbox = (Long_min,Lat_min,Long_max,Lat_max,)
# remove_stops_outsidebbox = True
# append_definitions = True

# loaded_feeds = ua.gtfs.load.gtfsfeed_to_df(gtfsfeed_path=None,
#                                            validation=validation,
#                                            verbose=verbose,
#                                            bbox=bbox,
#                                            remove_stops_outsidebbox=remove_stops_outsidebbox,
#                                            append_definitions=append_definitions)

# %% [markdown]
# # Variables

# %%
# timerange = ['00:00:00', '01:00:00']
# nombre_archivo = 'transit_0001.h5'
# timerange = ['01:00:00', '02:00:00']
# nombre_archivo = 'transit_0102.h5'
# timerange = ['02:00:00', '03:00:00'] # Transit not available
# nombre_archivo = 'transit_0203.h5'
# timerange = ['03:00:00', '04:00:00'] # Transit not available
# nombre_archivo = 'transit_0304.h5'
# timerange = ['04:00:00', '05:00:00'] # Transit not available
# nombre_archivo = 'transit_0405.h5'
# timerange = ['05:00:00', '06:00:00']
# nombre_archivo = 'transit_0506.h5'
# timerange = ['06:00:00', '07:00:00']
# nombre_archivo = 'transit_0607.h5'
# timerange = ['07:00:00', '08:00:00']
# nombre_archivo = 'transit_0708.h5'
# timerange = ['08:00:00', '09:00:00']
# nombre_archivo = 'transit_0809.h5'
# timerange = ['09:00:00', '10:00:00']
# nombre_archivo = 'transit_0910.h5'
# timerange = ['10:00:00', '11:00:00']
# nombre_archivo = 'transit_1011.h5'
# timerange = ['11:00:00', '12:00:00']
# nombre_archivo = 'transit_1112.h5'
# timerange = ['12:00:00', '13:00:00']
# nombre_archivo = 'transit_1213.h5'
# timerange = ['13:00:00', '14:00:00']
# nombre_archivo = 'transit_1314.h5'
# timerange = ['14:00:00', '15:00:00']
# nombre_archivo = 'transit_1415.h5'
# timerange = ['15:00:00', '16:00:00']
# nombre_archivo = 'transit_1516.h5'
# timerange = ['16:00:00', '17:00:00']
# nombre_archivo = 'transit_1617.h5'
# timerange = ['17:00:00', '18:00:00']
# nombre_archivo = 'transit_1718.h5'
# timerange = ['18:00:00', '19:00:00']
# nombre_archivo = 'transit_1819.h5'
# timerange = ['19:00:00', '20:00:00']
# nombre_archivo = 'transit_1920.h5'
# timerange = ['20:00:00', '21:00:00']
# nombre_archivo = 'transit_2021.h5'
# timerange = ['21:00:00', '22:00:00']
# nombre_archivo = 'transit_2122.h5'
# timerange = ['22:00:00', '23:00:00']
# nombre_archivo = 'transit_2223.h5'
timerange = ['23:00:00', '24:00:00']
nombre_archivo = 'transit_2324.h5'

# %% [markdown]
# # Create a transit network

# %%
ua.gtfs.network.create_transit_net(gtfsfeeds_dfs=loaded_feeds,
                                   day='monday',
                                   timerange=timerange,
                                   calendar_dates_lookup=None)

# I call the network urbanaccess_net

urbanaccess_net = ua.network.ua_network

#urbanaccess_net.transit_edges.head(25)
#urbanaccess_net.transit_nodes.head(25)
# urbanaccess_net.transit_nodes.plot(kind='scatter', x='x', y='y', s=0.1)
# Out:
# INFO:urbanaccess:Using calendar to extract service_ids to select trips.
# INFO:urbanaccess:21 service_ids were extracted from calendar
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were found in calendar for GTFS feed(s): ['lurraldebus renteria', 'lurraldebus areizaga', 'lurraldebus lasarte', 'lurraldebus arrasate', 'lurraldebus oiartzun', 'dbus', 'lurraldebus goierrialdea', 'lurraldebus ekialdebus', 'lurraldebus auif urb', 'lurraldebus tbh', 'lurraldebus tsst', 'lurraldebus tolosaldea', 'lurraldebus garayar', 'lurraldebus eibar', 'lurraldebus euskotren bus', 'lurraldebus zarautz', 'lurraldebus hernani']
# WARNING:urbanaccess:NOTE: If you expected more trips to have been extracted and your GTFS feed(s) have a calendar_dates file, consider utilizing the calendar_dates_lookup parameter in order to add additional trips based on information inside of calendar_dates. This should only be done if you know the corresponding GTFS feed is using calendar_dates instead of calendar to specify service_ids. When in doubt do not use the calendar_dates_lookup parameter.
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus renteria
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus areizaga
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus arrasate
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: dbus
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus goierrialdea
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus ekialdebus
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus auif urb
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus tbh
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus tolosaldea
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus garayar
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus eibar
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus euskotren bus
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus zarautz
# INFO:urbanaccess:14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus hernani
# INFO:urbanaccess:14,383 of 40,899 total trips were extracted representing calendar day: monday. Took 0.23 seconds
# Using calendar to extract service_ids to select trips.
# 21 service_ids were extracted from calendar
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were found in calendar for GTFS feed(s): ['lurraldebus renteria', 'lurraldebus areizaga', 'lurraldebus lasarte', 'lurraldebus arrasate', 'lurraldebus oiartzun', 'dbus', 'lurraldebus goierrialdea', 'lurraldebus ekialdebus', 'lurraldebus auif urb', 'lurraldebus tbh', 'lurraldebus tsst', 'lurraldebus tolosaldea', 'lurraldebus garayar', 'lurraldebus eibar', 'lurraldebus euskotren bus', 'lurraldebus zarautz', 'lurraldebus hernani']
# NOTE: If you expected more trips to have been extracted and your GTFS feed(s) have a calendar_dates file, consider utilizing the calendar_dates_lookup parameter in order to add additional trips based on information inside of calendar_dates. This should only be done if you know the corresponding GTFS feed is using calendar_dates instead of calendar to specify service_ids. When in doubt do not use the calendar_dates_lookup parameter.
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus renteria
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus areizaga
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus arrasate
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: dbus
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus goierrialdea
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus ekialdebus
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus auif urb
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus tbh
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus tolosaldea
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus garayar
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus eibar
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus euskotren bus
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus zarautz
# 14,383 trip(s) 35.17 percent of 40,899 total trip records were not found in calendar for GTFS feed: lurraldebus hernani
# 14,383 of 40,899 total trips were extracted representing calendar day: monday. Took 0.23 seconds
# INFO:urbanaccess:There are no departure time records missing from trips following the specified schedule. There are no records to interpolate.
# There are no departure time records missing from trips following the specified schedule. There are no records to interpolate.
# INFO:urbanaccess:Difference between stop times has been successfully calculated. Took 0.07 seconds
# INFO:urbanaccess:Stop times from 23:00:00 to 24:00:00 successfully selected 1,332 records out of 250,048 total records (0.53 percent of total). Took 0.09 seconds
# INFO:urbanaccess:Starting transformation process for 104 total trips...
# Difference between stop times has been successfully calculated. Took 0.07 seconds
# Stop times from 23:00:00 to 24:00:00 successfully selected 1,332 records out of 250,048 total records (0.53 percent of total). Took 0.09 seconds
# Starting transformation process for 104 total trips...
# INFO:urbanaccess:stop time table transformation to Pandana format edge table completed. Took 0.30 seconds
# INFO:urbanaccess:Time conversion completed: seconds converted to minutes.
# INFO:urbanaccess:531 of 2,292 records selected from stops. Took 0.01 seconds
# INFO:urbanaccess:stop time table transformation to Pandana format node table completed. Took 0.01 seconds
# stop time table transformation to Pandana format edge table completed. Took 0.30 seconds
# Time conversion completed: seconds converted to minutes.
# 531 of 2,292 records selected from stops. Took 0.01 seconds
# stop time table transformation to Pandana format node table completed. Took 0.01 seconds
# INFO:urbanaccess:route type successfully joined to transit edges. Took 1.01 seconds
# INFO:urbanaccess:route id successfully joined to transit edges. Took 0.09 seconds
# INFO:urbanaccess:Successfully created transit network. Took 3.81 seconds
# route type successfully joined to transit edges. Took 1.01 seconds
# route id successfully joined to transit edges. Took 0.09 seconds
# Successfully created transit network. Took 3.81 seconds

# %% [markdown]
# # Create a pedestrian network

# %%
# nodes, edges = ua.osm.load.ua_network_from_bbox(bbox=bbox,
#                                                 remove_lcn=True)
# # Create the network itself

# ua.osm.network.create_osm_net(osm_edges=edges,
#                               osm_nodes=nodes,
#                               travel_speed_mph=3)

# %% [markdown]
# # Create an integrated transit and pedestrian network

# %%
ua.network.integrate_network(urbanaccess_network=urbanaccess_net,
                             headways=False)
# Out:
# INFO:urbanaccess:Loaded UrbanAccess network components comprised of:
# INFO:urbanaccess:     Transit: 531 nodes and 1,228 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes and 300,118 edges
# Loaded UrbanAccess network components comprised of:
#      Transit: 531 nodes and 1,228 edges;
#      OSM: 110,744 nodes and 300,118 edges
# INFO:urbanaccess:Connector edges between the OSM and transit network nodes successfully completed. Took 0.45 seconds
# Connector edges between the OSM and transit network nodes successfully completed. Took 0.45 seconds
# INFO:urbanaccess:Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 3.82 seconds
# INFO:urbanaccess:Network edge and node network integration completed successfully resulting in a total of 111,275 nodes and 302,408 edges:
# INFO:urbanaccess:     Transit: 531 nodes 1,228 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes 300,118 edges; and
# INFO:urbanaccess:     OSM/Transit connector: 1,062 edges.
# Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 3.82 seconds
# Network edge and node network integration completed successfully resulting in a total of 111,275 nodes and 302,408 edges:
#      Transit: 531 nodes 1,228 edges;
#      OSM: 110,744 nodes 300,118 edges; and
#      OSM/Transit connector: 1,062 edges.

# %% [markdown]
# # Add average headways to network travel time

# %% [markdown]
# The network we have generated so far only contains pure travel times. UrbanAccess allows for the calculation of and addition of route stop level average headways to the network. This is used as a proxy for passenger wait times at stops and stations. The route stop level average headway are added to the pedestrian to transit connector edges.
#
# Let's calculate headways for the same AM Peak time period. Statistics on route stop level headways will be added to your GTFS transit data object inside of headways

# %%
ua.gtfs.headways.headways(gtfsfeeds_df=loaded_feeds,
                          headway_timerange=timerange)
loaded_feeds.headways

ua.network.integrate_network(urbanaccess_network=urbanaccess_net,
                             headways=True,
                             urbanaccess_gtfsfeeds_df=loaded_feeds,
                             headway_statistic='mean')
# Out:
# INFO:urbanaccess:Stop times from 23:00:00 to 24:00:00 successfully selected 1,332 records out of 250,048 total records (0.53 percent of total). Took 0.00 seconds
# Stop times from 23:00:00 to 24:00:00 successfully selected 1,332 records out of 250,048 total records (0.53 percent of total). Took 0.00 seconds
# INFO:urbanaccess:Starting route stop headway calculation for 629 route stops...
# Starting route stop headway calculation for 629 route stops...
# INFO:urbanaccess:Route stop headway calculation complete. Took 1.34 seconds
# INFO:urbanaccess:headway calculation complete. Took 1.51 seconds
# INFO:urbanaccess:Loaded UrbanAccess network components comprised of:
# INFO:urbanaccess:     Transit: 531 nodes and 1,228 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes and 300,118 edges
# INFO:urbanaccess:routes successfully joined to transit nodes. Took 0.02 seconds
# Route stop headway calculation complete. Took 1.34 seconds
# headway calculation complete. Took 1.51 seconds
# Loaded UrbanAccess network components comprised of:
#      Transit: 531 nodes and 1,228 edges;
#      OSM: 110,744 nodes and 300,118 edges
# routes successfully joined to transit nodes. Took 0.02 seconds
# INFO:urbanaccess:Connector edges between the OSM and transit network nodes successfully completed. Took 0.33 seconds
# INFO:urbanaccess:mean route stop headway will be used for pedestrian to transit edge impedance.
# INFO:urbanaccess:Headway impedance calculation completed. Took 0.02 seconds
# Connector edges between the OSM and transit network nodes successfully completed. Took 0.33 seconds
# mean route stop headway will be used for pedestrian to transit edge impedance.
# Headway impedance calculation completed. Took 0.02 seconds
# INFO:urbanaccess:Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 3.11 seconds
# INFO:urbanaccess:Network edge and node network integration completed successfully resulting in a total of 111,370 nodes and 303,301 edges:
# INFO:urbanaccess:     Transit: 626 nodes 1,228 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes 300,118 edges; and
# INFO:urbanaccess:     OSM/Transit connector: 1,955 edges.
# Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 3.11 seconds
# Network edge and node network integration completed successfully resulting in a total of 111,370 nodes and 303,301 edges:
#      Transit: 626 nodes 1,228 edges;
#      OSM: 110,744 nodes 300,118 edges; and
#      OSM/Transit connector: 1,955 edges.

# %% [markdown]
# # Create and save

# %%
s_time = time.time()
transit_ped_net = pdna.network.Network(urbanaccess_net.net_nodes["x"],
                               urbanaccess_net.net_nodes["y"],
                               urbanaccess_net.net_edges["from_int"],
                               urbanaccess_net.net_edges["to_int"],
                               urbanaccess_net.net_edges[["weight"]],
                               twoway=False)
print('Took {:,.2f} seconds'.format(time.time() - s_time))
# Out:
# Took 16.47 seconds

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
transit_ped_net.save_hdf5(f'/content/drive/MyDrive/Mobility_Choice/input_data/transit_24h/{nombre_archivo}')

# %%
edgecolor = ua.plot.col_colors(df=urbanaccess_net.net_edges, col='weight', cmap='gist_heat_r', num_bins=5)

ua.plot.plot_net(nodes=urbanaccess_net.net_nodes,
                 edges=urbanaccess_net.net_edges[urbanaccess_net.net_edges['net_type']=='transit'],
                 bbox=bbox,
                 fig_height=30, margin=0.02,
                 edge_color=edgecolor, edge_linewidth=1, edge_alpha=1,
                 node_color='black', node_size=0, node_alpha=1, node_edgecolor='none', node_zorder=3, nodes_only=False)
# Out:
# INFO:urbanaccess:Figure created. Took 0.56 seconds
# Figure created. Took 0.56 seconds
# (<Figure size 5301.42x3000 with 1 Axes>, <Axes: >)
