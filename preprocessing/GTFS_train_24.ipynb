# %% [markdown]
# # Import libraries and mount drive

# %%
# import numpy as np
# #import pandas as pd
# import os
# import glob
# #import matplotlib.pyplot as plt
# import statistics
# import seaborn as sns
# from pathlib import Path
# import re
# import requests
# from io import StringIO
# import random
# import pdb

# import matplotlib
# matplotlib.use('agg')  # allows notebook to be tested in Travis

# import pandas as pd
# #import cartopy.crs as ccrs
# #import cartopy
# import matplotlib.pyplot as plt
# #import pandana as pdna
# import time

# !pip install pandana
# import pandana as pdna

# # !pip install cartopy
# # import cartopy.crs as ccrs
# # import cartopy

# !pip install urbanaccess
# import urbanaccess as ua
# from urbanaccess.config import settings
# from urbanaccess.gtfsfeeds import feeds
# from urbanaccess import gtfsfeeds
# from urbanaccess.gtfs.gtfsfeeds_dataframe import gtfsfeeds_dfs
# from urbanaccess.network import ua_network, load_network

# %matplotlib inline

# %% [markdown]
# # Load data to an Urban Access transit data object

# %%
# # I manually add all the feeds from the bus transit companies of Gipuzkoa

# feeds.add_feed(add_dict={'Euskotren': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/Euskotren/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_areizaga': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/Renfe/google_transit.zip'})
# feeds.add_feed(add_dict={'lurraldebus_arrasate': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/Renfe_Cercanias/google_transit.zip'})

# # I download all these feeds, 40sg
# gtfsfeeds.download()

# %% [markdown]
# Let's specify a bounding box of coordinates for Gipuzkoa to subset the GTFS data to. You can generate a bounding box by going to http://boundingbox.klokantech.com/ and selecting the CSV format.

# %%
# # Load GTFS data into an UrbanAcess transit data object
# validation = True
# verbose = True
# # bbox for Gipuzkoa
# Lat_min = 42.904155
# Long_min = -2.621987
# Lat_max = 43.403070
# Long_max = -1.740334
# bbox = (Long_min,Lat_min,Long_max,Lat_max,)
# remove_stops_outsidebbox = True
# append_definitions = True

# loaded_feeds = ua.gtfs.load.gtfsfeed_to_df(gtfsfeed_path=None,
#                                            validation=validation,
#                                            verbose=verbose,
#                                            bbox=bbox,
#                                            remove_stops_outsidebbox=remove_stops_outsidebbox,
#                                            append_definitions=append_definitions)

# %% [markdown]
# # Variables

# %%
# timerange = ['00:00:00', '01:00:00'] # Train not available
# nombre_archivo = 'train_0001.h5'
# timerange = ['01:00:00', '02:00:00'] # Train not available
# nombre_archivo = 'train_0102.h5'
# timerange = ['02:00:00', '03:00:00'] # Train not available
# nombre_archivo = 'train_0203.h5'
# timerange = ['03:00:00', '04:00:00'] # Train not available
# nombre_archivo = 'train_0304.h5'
# timerange = ['04:00:00', '05:00:00'] # Train not available
# nombre_archivo = 'train_0405.h5'
# timerange = ['05:00:00', '06:00:00']
# nombre_archivo = 'train_0506.h5'
# timerange = ['06:00:00', '07:00:00']
# nombre_archivo = 'train_0607.h5'
# timerange = ['07:00:00', '08:00:00']
# nombre_archivo = 'train_0708.h5'
# timerange = ['08:00:00', '09:00:00']
# nombre_archivo = 'train_0809.h5'
# timerange = ['09:00:00', '10:00:00']
# nombre_archivo = 'train_0910.h5'
# timerange = ['10:00:00', '11:00:00']
# nombre_archivo = 'train_1011.h5'
# timerange = ['11:00:00', '12:00:00']
# nombre_archivo = 'train_1112.h5'
# timerange = ['12:00:00', '13:00:00']
# nombre_archivo = 'train_1213.h5'
# timerange = ['13:00:00', '14:00:00']
# nombre_archivo = 'train_1314.h5'
# timerange = ['14:00:00', '15:00:00']
# nombre_archivo = 'train_1415.h5'
# timerange = ['15:00:00', '16:00:00']
# nombre_archivo = 'train_1516.h5'
# timerange = ['16:00:00', '17:00:00']
# nombre_archivo = 'train_1617.h5'
# timerange = ['17:00:00', '18:00:00']
# nombre_archivo = 'train_1718.h5'
# timerange = ['18:00:00', '19:00:00']
# nombre_archivo = 'train_1819.h5'
# timerange = ['19:00:00', '20:00:00']
# nombre_archivo = 'train_1920.h5'
# timerange = ['20:00:00', '21:00:00']
# nombre_archivo = 'train_2021.h5'
# timerange = ['21:00:00', '22:00:00']
# nombre_archivo = 'train_2122.h5'
# timerange = ['22:00:00', '23:00:00']
# nombre_archivo = 'train_2223.h5'
timerange = ['23:00:00', '24:00:00']
nombre_archivo = 'train_2324.h5'

# %% [markdown]
# # Create a train network

# %%
ua.gtfs.network.create_transit_net(gtfsfeeds_dfs=loaded_feeds,
                                   day='monday',
                                   timerange=timerange,
                                   calendar_dates_lookup=None)

# I call the network urbanaccess_net

urbanaccess_net = ua.network.ua_network

urbanaccess_net.transit_edges.head(25)
urbanaccess_net.transit_nodes.head(25)
# urbanaccess_net.transit_nodes.plot(kind='scatter', x='x', y='y', s=0.1)
# Out:
# INFO:urbanaccess:Using calendar to extract service_ids to select trips.
# INFO:urbanaccess:11,406 service_ids were extracted from calendar
# INFO:urbanaccess:35,304 trip(s) 24.81 percent of 142,307 total trip records were found in calendar for GTFS feed(s): ['euskotren', 'lurraldebus areizaga', 'lurraldebus arrasate']
# WARNING:urbanaccess:NOTE: If you expected more trips to have been extracted and your GTFS feed(s) have a calendar_dates file, consider utilizing the calendar_dates_lookup parameter in order to add additional trips based on information inside of calendar_dates. This should only be done if you know the corresponding GTFS feed is using calendar_dates instead of calendar to specify service_ids. When in doubt do not use the calendar_dates_lookup parameter.
# INFO:urbanaccess:35,304 trip(s) 24.81 percent of 142,307 total trip records were not found in calendar for GTFS feed: euskotren
# INFO:urbanaccess:35,304 trip(s) 24.81 percent of 142,307 total trip records were not found in calendar for GTFS feed: lurraldebus arrasate
# INFO:urbanaccess:35,304 of 142,307 total trips were extracted representing calendar day: monday. Took 0.14 seconds
# INFO:urbanaccess:There are no departure time records missing from trips following the specified schedule. There are no records to interpolate.
# INFO:urbanaccess:Difference between stop times has been successfully calculated. Took 0.00 seconds
# INFO:urbanaccess:Stop times from 23:00:00 to 24:00:00 successfully selected 228 records out of 22,371 total records (1.02 percent of total). Took 0.00 seconds
# INFO:urbanaccess:Starting transformation process for 32 total trips...
# Using calendar to extract service_ids to select trips.
# 11,406 service_ids were extracted from calendar
# 35,304 trip(s) 24.81 percent of 142,307 total trip records were found in calendar for GTFS feed(s): ['euskotren', 'lurraldebus areizaga', 'lurraldebus arrasate']
# NOTE: If you expected more trips to have been extracted and your GTFS feed(s) have a calendar_dates file, consider utilizing the calendar_dates_lookup parameter in order to add additional trips based on information inside of calendar_dates. This should only be done if you know the corresponding GTFS feed is using calendar_dates instead of calendar to specify service_ids. When in doubt do not use the calendar_dates_lookup parameter.
# 35,304 trip(s) 24.81 percent of 142,307 total trip records were not found in calendar for GTFS feed: euskotren
# 35,304 trip(s) 24.81 percent of 142,307 total trip records were not found in calendar for GTFS feed: lurraldebus arrasate
# 35,304 of 142,307 total trips were extracted representing calendar day: monday. Took 0.14 seconds
# There are no departure time records missing from trips following the specified schedule. There are no records to interpolate.
# Difference between stop times has been successfully calculated. Took 0.00 seconds
# Stop times from 23:00:00 to 24:00:00 successfully selected 228 records out of 22,371 total records (1.02 percent of total). Took 0.00 seconds
# Starting transformation process for 32 total trips...
# INFO:urbanaccess:stop time table transformation to Pandana format edge table completed. Took 0.04 seconds
# INFO:urbanaccess:Time conversion completed: seconds converted to minutes.
# INFO:urbanaccess:48 of 220 records selected from stops. Took 0.00 seconds
# INFO:urbanaccess:stop time table transformation to Pandana format node table completed. Took 0.01 seconds
# INFO:urbanaccess:route type successfully joined to transit edges. Took 0.04 seconds
# INFO:urbanaccess:route id successfully joined to transit edges. Took 0.12 seconds
# INFO:urbanaccess:Successfully created transit network. Took 0.46 seconds
# stop time table transformation to Pandana format edge table completed. Took 0.04 seconds
# Time conversion completed: seconds converted to minutes.
# 48 of 220 records selected from stops. Took 0.00 seconds
# stop time table transformation to Pandana format node table completed. Took 0.01 seconds
# route type successfully joined to transit edges. Took 0.04 seconds
# route id successfully joined to transit edges. Took 0.12 seconds
# Successfully created transit network. Took 0.46 seconds
#                                                  x          y  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena -1.981479  43.312861
# ES:Euskotren:Quay:25821:_euskotren_trena -1.782226  43.352453
# ES:Euskotren:Quay:25892:_euskotren_trena -1.796039  43.341206
# ES:Euskotren:Quay:25901:_euskotren_trena -1.975286  43.302049
# ES:Euskotren:Quay:26032:_euskotren_trena -2.615750  43.166630
# ES:Euskotren:Quay:26081:_euskotren_trena -1.968383  43.310179
# ES:Euskotren:Quay:26122:_euskotren_trena -1.879715  43.308530
# ES:Euskotren:Quay:26211:_euskotren_trena -2.000204  43.302646
# ES:Euskotren:Quay:26242:_euskotren_trena -1.937832  43.320059
# ES:Euskotren:Quay:26252:_euskotren_trena -1.889402  43.308227
# ES:Euskotren:Quay:26312:_euskotren_trena -1.929814  43.316674
# ES:Euskotren:Quay:26322:_euskotren_trena -1.816976  43.330444
# ES:Euskotren:Quay:26361:_euskotren_trena -1.803734  43.336518
# ES:Euskotren:Quay:26471:_euskotren_trena -1.994390  43.291369
# ES:Euskotren:Quay:26481:_euskotren_trena -1.954765  43.314918
# ES:Euskotren:Quay:26492:_euskotren_trena -1.786391  43.349479
# ES:Euskotren:Quay:26511:_euskotren_trena -2.006861  43.278965
# ES:Euskotren:Quay:26531:_euskotren_trena -2.053019  43.268642
# ES:Euskotren:Quay:26542:_euskotren_trena -1.857721  43.326705
# ES:Euskotren:Quay:26652:_euskotren_trena -1.899344  43.311197
# 11305_renfe_cercanias                    -2.334469  43.019887
# 11306_renfe_cercanias                    -2.329396  43.052263
# 11400_renfe_cercanias                    -2.318462  43.088273
# 11402_renfe_cercanias                    -2.255831  43.040151
# 11404_renfe_cercanias                    -2.203234  43.046174
#
#                                          unique_agency_id  route_type  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:25821:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:25892:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:25901:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26032:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26081:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26122:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26211:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26242:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26252:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26312:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26322:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26361:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26471:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26481:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26492:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26511:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26531:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26542:_euskotren_trena  euskotren_trena         2.0
# ES:Euskotren:Quay:26652:_euskotren_trena  euskotren_trena         2.0
# 11305_renfe_cercanias                     renfe_cercanias         NaN
# 11306_renfe_cercanias                     renfe_cercanias         NaN
# 11400_renfe_cercanias                     renfe_cercanias         NaN
# 11402_renfe_cercanias                     renfe_cercanias         NaN
# 11404_renfe_cercanias                     renfe_cercanias         NaN
#
#                                                            stop_id  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena  ES:Euskotren:Quay:25811:
# ES:Euskotren:Quay:25821:_euskotren_trena  ES:Euskotren:Quay:25821:
# ES:Euskotren:Quay:25892:_euskotren_trena  ES:Euskotren:Quay:25892:
# ES:Euskotren:Quay:25901:_euskotren_trena  ES:Euskotren:Quay:25901:
# ES:Euskotren:Quay:26032:_euskotren_trena  ES:Euskotren:Quay:26032:
# ES:Euskotren:Quay:26081:_euskotren_trena  ES:Euskotren:Quay:26081:
# ES:Euskotren:Quay:26122:_euskotren_trena  ES:Euskotren:Quay:26122:
# ES:Euskotren:Quay:26211:_euskotren_trena  ES:Euskotren:Quay:26211:
# ES:Euskotren:Quay:26242:_euskotren_trena  ES:Euskotren:Quay:26242:
# ES:Euskotren:Quay:26252:_euskotren_trena  ES:Euskotren:Quay:26252:
# ES:Euskotren:Quay:26312:_euskotren_trena  ES:Euskotren:Quay:26312:
# ES:Euskotren:Quay:26322:_euskotren_trena  ES:Euskotren:Quay:26322:
# ES:Euskotren:Quay:26361:_euskotren_trena  ES:Euskotren:Quay:26361:
# ES:Euskotren:Quay:26471:_euskotren_trena  ES:Euskotren:Quay:26471:
# ES:Euskotren:Quay:26481:_euskotren_trena  ES:Euskotren:Quay:26481:
# ES:Euskotren:Quay:26492:_euskotren_trena  ES:Euskotren:Quay:26492:
# ES:Euskotren:Quay:26511:_euskotren_trena  ES:Euskotren:Quay:26511:
# ES:Euskotren:Quay:26531:_euskotren_trena  ES:Euskotren:Quay:26531:
# ES:Euskotren:Quay:26542:_euskotren_trena  ES:Euskotren:Quay:26542:
# ES:Euskotren:Quay:26652:_euskotren_trena  ES:Euskotren:Quay:26652:
# 11305_renfe_cercanias                                        11305
# 11306_renfe_cercanias                                        11306
# 11400_renfe_cercanias                                        11400
# 11402_renfe_cercanias                                        11402
# 11404_renfe_cercanias                                        11404
#
#                                                                 stop_name  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena                   Amara-Donostia
# ES:Euskotren:Quay:25821:_euskotren_trena                          Hendaia
# ES:Euskotren:Quay:25892:_euskotren_trena                             Irun
# ES:Euskotren:Quay:25901:_euskotren_trena                  Anoeta-Donostia
# ES:Euskotren:Quay:26032:_euskotren_trena                    Traña-Abadiño
# ES:Euskotren:Quay:26081:_euskotren_trena                  Loiola-Donostia
# ES:Euskotren:Quay:26122:_euskotren_trena                         Oiartzun
# ES:Euskotren:Quay:26211:_euskotren_trena                Lugaritz-Donostia
# ES:Euskotren:Quay:26242:_euskotren_trena                 Herrera-Donostia
# ES:Euskotren:Quay:26252:_euskotren_trena              Fanderia-Errenteria
# ES:Euskotren:Quay:26312:_euskotren_trena                   Altza-Donostia
# ES:Euskotren:Quay:26322:_euskotren_trena                      Bentak-Irun
# ES:Euskotren:Quay:26361:_euskotren_trena                 Belaskoenea-Irun
# ES:Euskotren:Quay:26471:_euskotren_trena                  Añorga-Donostia
# ES:Euskotren:Quay:26481:_euskotren_trena            Intxaurrondo-Donostia
# ES:Euskotren:Quay:26492:_euskotren_trena                      Ficoba-Irun
# ES:Euskotren:Quay:26511:_euskotren_trena               Errekalde-Donostia
# ES:Euskotren:Quay:26531:_euskotren_trena                          Usurbil
# ES:Euskotren:Quay:26542:_euskotren_trena              Gaintxurizketa-Lezo
# ES:Euskotren:Quay:26652:_euskotren_trena                       Errenteria
# 11305_renfe_cercanias                     Estación de tren Brinkola-OÑati
# 11306_renfe_cercanias                            Estación de tren Legazpi
# 11400_renfe_cercanias                          Estación de tren Zumarraga
# 11402_renfe_cercanias                        Estación de tren Ormaiztegui
# 11404_renfe_cercanias                            Estación de tren Beasain
#
#                                                         parent_station  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena  ES:Euskotren:StopPlace:2581:
# ES:Euskotren:Quay:25821:_euskotren_trena  ES:Euskotren:StopPlace:2582:
# ES:Euskotren:Quay:25892:_euskotren_trena  ES:Euskotren:StopPlace:2589:
# ES:Euskotren:Quay:25901:_euskotren_trena  ES:Euskotren:StopPlace:2590:
# ES:Euskotren:Quay:26032:_euskotren_trena  ES:Euskotren:StopPlace:2603:
# ES:Euskotren:Quay:26081:_euskotren_trena  ES:Euskotren:StopPlace:2608:
# ES:Euskotren:Quay:26122:_euskotren_trena  ES:Euskotren:StopPlace:2612:
# ES:Euskotren:Quay:26211:_euskotren_trena  ES:Euskotren:StopPlace:2621:
# ES:Euskotren:Quay:26242:_euskotren_trena  ES:Euskotren:StopPlace:2624:
# ES:Euskotren:Quay:26252:_euskotren_trena  ES:Euskotren:StopPlace:2625:
# ES:Euskotren:Quay:26312:_euskotren_trena  ES:Euskotren:StopPlace:2631:
# ES:Euskotren:Quay:26322:_euskotren_trena  ES:Euskotren:StopPlace:2632:
# ES:Euskotren:Quay:26361:_euskotren_trena  ES:Euskotren:StopPlace:2636:
# ES:Euskotren:Quay:26471:_euskotren_trena  ES:Euskotren:StopPlace:2647:
# ES:Euskotren:Quay:26481:_euskotren_trena  ES:Euskotren:StopPlace:2648:
# ES:Euskotren:Quay:26492:_euskotren_trena  ES:Euskotren:StopPlace:2649:
# ES:Euskotren:Quay:26511:_euskotren_trena  ES:Euskotren:StopPlace:2651:
# ES:Euskotren:Quay:26531:_euskotren_trena  ES:Euskotren:StopPlace:2653:
# ES:Euskotren:Quay:26542:_euskotren_trena  ES:Euskotren:StopPlace:2654:
# ES:Euskotren:Quay:26652:_euskotren_trena  ES:Euskotren:StopPlace:2665:
# 11305_renfe_cercanias                                              NaN
# 11306_renfe_cercanias                                              NaN
# 11400_renfe_cercanias                                              NaN
# 11402_renfe_cercanias                                              NaN
# 11404_renfe_cercanias                                              NaN
#
#                                           stop_code  wheelchair_boarding  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:25821:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:25892:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:25901:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26032:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26081:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26122:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26211:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26242:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26252:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26312:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26322:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26361:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26471:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26481:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26492:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26511:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26531:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26542:_euskotren_trena        NaN                  0.0
# ES:Euskotren:Quay:26652:_euskotren_trena        NaN                  0.0
# 11305_renfe_cercanias                           NaN                  NaN
# 11306_renfe_cercanias                           NaN                  NaN
# 11400_renfe_cercanias                           NaN                  NaN
# 11402_renfe_cercanias                           NaN                  NaN
# 11404_renfe_cercanias                           NaN                  NaN
#
#                                                         zone_id  \
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:25821:_euskotren_trena  ES:Euskotren:Zone:43:
# ES:Euskotren:Quay:25892:_euskotren_trena  ES:Euskotren:Zone:43:
# ES:Euskotren:Quay:25901:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26032:_euskotren_trena   ES:Euskotren:Zone:7:
# ES:Euskotren:Quay:26081:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26122:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26211:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26242:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26252:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26312:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26322:_euskotren_trena  ES:Euskotren:Zone:43:
# ES:Euskotren:Quay:26361:_euskotren_trena  ES:Euskotren:Zone:43:
# ES:Euskotren:Quay:26471:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26481:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26492:_euskotren_trena  ES:Euskotren:Zone:43:
# ES:Euskotren:Quay:26511:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26531:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26542:_euskotren_trena  ES:Euskotren:Zone:42:
# ES:Euskotren:Quay:26652:_euskotren_trena  ES:Euskotren:Zone:42:
# 11305_renfe_cercanias                                       NaN
# 11306_renfe_cercanias                                       NaN
# 11400_renfe_cercanias                                       NaN
# 11402_renfe_cercanias                                       NaN
# 11404_renfe_cercanias                                       NaN
#
#                                           location_type net_type
# node_id
# ES:Euskotren:Quay:25811:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:25821:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:25892:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:25901:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26032:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26081:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26122:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26211:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26242:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26252:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26312:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26322:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26361:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26471:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26481:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26492:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26511:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26531:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26542:_euskotren_trena            0.0  transit
# ES:Euskotren:Quay:26652:_euskotren_trena            0.0  transit
# 11305_renfe_cercanias                               NaN  transit
# 11306_renfe_cercanias                               NaN  transit
# 11400_renfe_cercanias                               NaN  transit
# 11402_renfe_cercanias                               NaN  transit
# 11404_renfe_cercanias                               NaN  transit

# %% [markdown]
# # Create a pedestrian network

# %%
# nodes, edges = ua.osm.load.ua_network_from_bbox(bbox=bbox,
#                                                 remove_lcn=True)
# # Create the network itself

# ua.osm.network.create_osm_net(osm_edges=edges,
#                               osm_nodes=nodes,
#                               travel_speed_mph=3)

# %% [markdown]
# # Create an integrated transit and pedestrian network

# %%
ua.network.integrate_network(urbanaccess_network=urbanaccess_net,
                             headways=False)
# Out:
# INFO:urbanaccess:Loaded UrbanAccess network components comprised of:
# INFO:urbanaccess:     Transit: 48 nodes and 196 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes and 300,118 edges
# INFO:urbanaccess:Connector edges between the OSM and transit network nodes successfully completed. Took 0.06 seconds
# Loaded UrbanAccess network components comprised of:
#      Transit: 48 nodes and 196 edges;
#      OSM: 110,744 nodes and 300,118 edges
# Connector edges between the OSM and transit network nodes successfully completed. Took 0.06 seconds
# INFO:urbanaccess:Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 1.90 seconds
# INFO:urbanaccess:Network edge and node network integration completed successfully resulting in a total of 110,792 nodes and 300,410 edges:
# INFO:urbanaccess:     Transit: 48 nodes 196 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes 300,118 edges; and
# INFO:urbanaccess:     OSM/Transit connector: 96 edges.
# Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 1.90 seconds
# Network edge and node network integration completed successfully resulting in a total of 110,792 nodes and 300,410 edges:
#      Transit: 48 nodes 196 edges;
#      OSM: 110,744 nodes 300,118 edges; and
#      OSM/Transit connector: 96 edges.

# %% [markdown]
# # Add average headways to network travel time

# %% [markdown]
# The network we have generated so far only contains pure travel times. UrbanAccess allows for the calculation of and addition of route stop level average headways to the network. This is used as a proxy for passenger wait times at stops and stations. The route stop level average headway are added to the pedestrian to transit connector edges.
#
# Let's calculate headways for the same AM Peak time period. Statistics on route stop level headways will be added to your GTFS transit data object inside of headways

# %%
ua.gtfs.headways.headways(gtfsfeeds_df=loaded_feeds,
                          headway_timerange=timerange)
loaded_feeds.headways

ua.network.integrate_network(urbanaccess_network=urbanaccess_net,
                             headways=True,
                             urbanaccess_gtfsfeeds_df=loaded_feeds,
                             headway_statistic='mean')
# Out:
# INFO:urbanaccess:Stop times from 23:00:00 to 24:00:00 successfully selected 228 records out of 22,371 total records (1.02 percent of total). Took 0.00 seconds
# Stop times from 23:00:00 to 24:00:00 successfully selected 228 records out of 22,371 total records (1.02 percent of total). Took 0.00 seconds
# INFO:urbanaccess:Starting route stop headway calculation for 49 route stops...
# Starting route stop headway calculation for 49 route stops...
# INFO:urbanaccess:Route stop headway calculation complete. Took 0.10 seconds
# INFO:urbanaccess:headway calculation complete. Took 0.37 seconds
# INFO:urbanaccess:Loaded UrbanAccess network components comprised of:
# INFO:urbanaccess:     Transit: 48 nodes and 196 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes and 300,118 edges
# INFO:urbanaccess:routes successfully joined to transit nodes. Took 0.01 seconds
# Route stop headway calculation complete. Took 0.10 seconds
# headway calculation complete. Took 0.37 seconds
# Loaded UrbanAccess network components comprised of:
#      Transit: 48 nodes and 196 edges;
#      OSM: 110,744 nodes and 300,118 edges
# routes successfully joined to transit nodes. Took 0.01 seconds
# INFO:urbanaccess:Connector edges between the OSM and transit network nodes successfully completed. Took 0.08 seconds
# INFO:urbanaccess:mean route stop headway will be used for pedestrian to transit edge impedance.
# INFO:urbanaccess:Headway impedance calculation completed. Took 0.01 seconds
# Connector edges between the OSM and transit network nodes successfully completed. Took 0.08 seconds
# mean route stop headway will be used for pedestrian to transit edge impedance.
# Headway impedance calculation completed. Took 0.01 seconds
# INFO:urbanaccess:Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 2.30 seconds
# INFO:urbanaccess:Network edge and node network integration completed successfully resulting in a total of 110,792 nodes and 300,588 edges:
# INFO:urbanaccess:     Transit: 48 nodes 196 edges;
# INFO:urbanaccess:     OSM: 110,744 nodes 300,118 edges; and
# INFO:urbanaccess:     OSM/Transit connector: 274 edges.
# Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 2.30 seconds
# Network edge and node network integration completed successfully resulting in a total of 110,792 nodes and 300,588 edges:
#      Transit: 48 nodes 196 edges;
#      OSM: 110,744 nodes 300,118 edges; and
#      OSM/Transit connector: 274 edges.

# %% [markdown]
# # Create and save

# %%
s_time = time.time()
transit_ped_net = pdna.network.Network(urbanaccess_net.net_nodes["x"],
                               urbanaccess_net.net_nodes["y"],
                               urbanaccess_net.net_edges["from_int"],
                               urbanaccess_net.net_edges["to_int"],
                               urbanaccess_net.net_edges[["weight"]],
                               twoway=False)
print('Took {:,.2f} seconds'.format(time.time() - s_time))
# Out:
# Took 6.43 seconds

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
transit_ped_net.save_hdf5(f'/content/drive/MyDrive/Mobility_Choice/input_data/train_24h/{nombre_archivo}')

# %%
edgecolor = ua.plot.col_colors(df=urbanaccess_net.net_edges, col='weight', cmap='gist_heat_r', num_bins=5)

ua.plot.plot_net(nodes=urbanaccess_net.net_nodes,
                 edges=urbanaccess_net.net_edges[urbanaccess_net.net_edges['net_type']=='transit'],
                 bbox=bbox,
                 fig_height=30, margin=0.02,
                 edge_color=edgecolor, edge_linewidth=1, edge_alpha=1,
                 node_color='black', node_size=0, node_alpha=1, node_edgecolor='none', node_zorder=3, nodes_only=False)
# Out:
# INFO:urbanaccess:Figure created. Took 0.26 seconds
# Figure created. Took 0.26 seconds
# (<Figure size 5301.42x3000 with 1 Axes>, <Axes: >)
